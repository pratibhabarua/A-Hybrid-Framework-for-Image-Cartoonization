# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
prashantarorat_facial_key_point_data_path = kagglehub.dataset_download('prashantarorat/facial-key-point-data')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/facial-key-point-data/all_data.json
# /kaggle/input/facial-key-point-data/images/01301.png
# /kaggle/input/facial-key-point-data/images/02578.png
# /kaggle/input/facial-key-point-data/images/00929.png
# /kaggle/input/facial-key-point-data/images/04915.png
# /kaggle/input/facial-key-point-data/images/02630.png
# /kaggle/input/facial-key-point-data/images/03862.png
# /kaggle/input/facial-key-point-data/images/01883.png
# /kaggle/input/facial-key-point-data/images/00704.png
# /kaggle/input/facial-key-point-data/images/03163.png
# /kaggle/input/facial-key-point-data/images/01124.png
# /kaggle/input/facial-key-point-data/images/04159.png
# /kaggle/input/facial-key-point-data/images/01570.png
# /kaggle/input/facial-key-point-data/images/03092.png
# /kaggle/input/facial-key-point-data/images/03663.png
# /kaggle/input/facial-key-point-data/images/04084.png
# /kaggle/input/facial-key-point-data/images/04216.png
# /kaggle/input/facial-key-point-data/images/02640.png
# /kaggle/input/facial-key-point-data/images/02422.png
# /kaggle/input/facial-key-point-data/images/03434.png
# /kaggle/input/facial-key-point-data/images/02284.png
# /kaggle/input/facial-key-point-data/images/00562.png
# /kaggle/input/facial-key-point-data/images/02715.png
# /kaggle/input/facial-key-point-data/images/00237.png
# /kaggle/input/facial-key-point-data/images/02606.png
# /kaggle/input/facial-key-point-data/images/03852.png
# /kaggle/input/facial-key-point-data/images/02073.png
# /kaggle/input/facial-key-point-data/images/00406.png
# /kaggle/input/facial-key-point-data/images/01582.png
# /kaggle/input/facial-key-point-data/images/00448.png
# /kaggle/input/facial-key-point-data/images/01686.png
# /kaggle/input/facial-key-point-data/images/00255.png
# /kaggle/input/facial-key-point-data/images/00435.png
# /kaggle/input/facial-key-point-data/images/02247.png
# /kaggle/input/facial-key-point-data/images/00365.png
# /kaggle/input/facial-key-point-data/images/04766.png
# /kaggle/input/facial-key-point-data/images/04710.png
# /kaggle/input/facial-key-point-data/images/00105.png
# /kaggle/input/facial-key-point-data/images/02626.png
# /kaggle/input/facial-key-point-data/images/01574.png
# /kaggle/input/facial-key-point-data/images/03495.png
# /kaggle/input/facial-key-point-data/images/01523.png
# /kaggle/input/facial-key-point-data/images/01569.png
# /kaggle/input/facial-key-point-data/images/03895.png
# /kaggle/input/facial-key-point-data/images/01716.png
# /kaggle/input/facial-key-point-data/images/04645.png
# /kaggle/input/facial-key-point-data/images/01735.png
# /kaggle/input/facial-key-point-data/images/03508.png
# /kaggle/input/facial-key-point-data/images/04282.png
# /kaggle/input/facial-key-point-data/images/01829.png
# /kaggle/input/facial-key-point-data/images/00936.png
# /kaggle/input/facial-key-point-data/images/03289.png
# /kaggle/input/facial-key-point-data/images/00512.png
# /kaggle/input/facial-key-point-data/images/04117.png
# /kaggle/input/facial-key-point-data/images/04213.png
# /kaggle/input/facial-key-point-data/images/03041.png
# /kaggle/input/facial-key-point-data/images/02053.png
# /kaggle/input/facial-key-point-data/images/04234.png
# /kaggle/input/facial-key-point-data/images/00869.png
# /kaggle/input/facial-key-point-data/images/00669.png
# /kaggle/input/facial-key-point-data/images/00733.png
# /kaggle/input/facial-key-point-data/images/00657.png
# /kaggle/input/facial-key-point-data/images/00033.png
# /kaggle/input/facial-key-point-data/images/01606.png
# /kaggle/input/facial-key-point-data/images/03899.png
# /kaggle/input/facial-key-point-data/images/02821.png
# /kaggle/input/facial-key-point-data/images/01081.png
# /kaggle/input/facial-key-point-data/images/01748.png
# /kaggle/input/facial-key-point-data/images/03602.png
# /kaggle/input/facial-key-point-data/images/01595.png
# /kaggle/input/facial-key-point-data/images/04953.png
# /kaggle/input/facial-key-point-data/images/04849.png
# /kaggle/input/facial-key-point-data/images/01794.png
# /kaggle/input/facial-key-point-data/images/00096.png
# /kaggle/input/facial-key-point-data/images/04388.png
# /kaggle/input/facial-key-point-data/images/01550.png
# /kaggle/input/facial-key-point-data/images/02545.png
# /kaggle/input/facial-key-point-data/images/02472.png
# /kaggle/input/facial-key-point-data/images/00185.png
# /kaggle/input/facial-key-point-data/images/01363.png
# /kaggle/input/facial-key-point-data/images/02199.png
# /kaggle/input/facial-key-point-data/images/04865.png
# /kaggle/input/facial-key-point-data/images/04720.png
# /kaggle/input/facial-key-point-data/images/00238.png
# /kaggle/input/facial-key-point-data/images/02000.png
# /kaggle/input/facial-key-point-data/images/03422.png
# /kaggle/input/facial-key-point-data/images/01742.png
# /kaggle/input/facial-key-point-data/images/01790.png
# /kaggle/input/facial-key-point-data/images/04090.png
# /kaggle/input/facial-key-point-data/images/03684.png
# /kaggle/input/facial-key-point-data/images/04913.png
# /kaggle/input/facial-key-point-data/images/01774.png
# /kaggle/input/facial-key-point-data/images/01979.png
# /kaggle/input/facial-key-point-data/images/02192.png
# /kaggle/input/facial-key-point-data/images/01191.png
# /kaggle/input/facial-key-point-data/images/00488.png
# /kaggle/input/facial-key-point-data/images/01352.png
# /kaggle/input/facial-key-point-data/images/01594.png
# /kaggle/input/facial-key-point-data/images/00356.png
# /kaggle/input/facial-key-point-data/images/01793.png
# /kaggle/input/facial-key-point-data/images/03747.png
# /kaggle/input/facial-key-point-data/images/00082.png
# /kaggle/input/facial-key-point-data/images/01241.png
# /kaggle/input/facial-key-point-data/images/02362.png
# /kaggle/input/facial-key-point-data/images/02931.png
# /kaggle/input/facial-key-point-data/images/02176.png
# /kaggle/input/facial-key-point-data/images/00004.png
# /kaggle/input/facial-key-point-data/images/01820.png
# /kaggle/input/facial-key-point-data/images/01460.png
# /kaggle/input/facial-key-point-data/images/01783.png
# /kaggle/input/facial-key-point-data/images/04289.png
# /kaggle/input/facial-key-point-data/images/02105.png
# /kaggle/input/facial-key-point-data/images/04640.png
# /kaggle/input/facial-key-point-data/images/04122.png
# /kaggle/input/facial-key-point-data/images/04133.png
# /kaggle/input/facial-key-point-data/images/01334.png
# /kaggle/input/facial-key-point-data/images/04777.png
# /kaggle/input/facial-key-point-data/images/00305.png
# /kaggle/input/facial-key-point-data/images/04103.png
# /kaggle/input/facial-key-point-data/images/02594.png
# /kaggle/input/facial-key-point-data/images/04944.png
# /kaggle/input/facial-key-point-data/images/00124.png
# /kaggle/input/facial-key-point-data/images/03378.png
# /kaggle/input/facial-key-point-data/images/00874.png
# /kaggle/input/facial-key-point-data/images/02544.png
# /kaggle/input/facial-key-point-data/images/00023.png
# /kaggle/input/facial-key-point-data/images/01023.png
# /kaggle/input/facial-key-point-data/images/03814.png
# /kaggle/input/facial-key-point-data/images/02185.png
# /kaggle/input/facial-key-point-data/images/01499.png
# /kaggle/input/facial-key-point-data/images/01318.png
# /kaggle/input/facial-key-point-data/images/04596.png
# /kaggle/input/facial-key-point-data/images/03938.png
# /kaggle/input/facial-key-point-data/images/03017.png
# /kaggle/input/facial-key-point-data/images/04187.png
# /kaggle/input/facial-key-point-data/images/03975.png
# /kaggle/input/facial-key-point-data/images/00723.png
# /kaggle/input/facial-key-point-data/images/00145.png
# /kaggle/input/facial-key-point-data/images/00100.png
# /kaggle/input/facial-key-point-data/images/03479.png
# /kaggle/input/facial-key-point-data/images/03790.png
# /kaggle/input/facial-key-point-data/images/02241.png
# /kaggle/input/facial-key-point-data/images/01946.png
# /kaggle/input/facial-key-point-data/images/04272.png
# /kaggle/input/facial-key-point-data/images/02376.png
# /kaggle/input/facial-key-point-data/images/00041.png
# /kaggle/input/facial-key-point-data/images/00080.png
# /kaggle/input/facial-key-point-data/images/00298.png
# /kaggle/input/facial-key-point-data/images/04732.png
# /kaggle/input/facial-key-point-data/images/03698.png
# /kaggle/input/facial-key-point-data/images/01927.png
# /kaggle/input/facial-key-point-data/images/03164.png
# /kaggle/input/facial-key-point-data/images/04124.png
# /kaggle/input/facial-key-point-data/images/01021.png
# /kaggle/input/facial-key-point-data/images/00024.png
# /kaggle/input/facial-key-point-data/images/00239.png
# /kaggle/input/facial-key-point-data/images/04855.png
# /kaggle/input/facial-key-point-data/images/02352.png
# /kaggle/input/facial-key-point-data/images/01048.png
# /kaggle/input/facial-key-point-data/images/01696.png
# /kaggle/input/facial-key-point-data/images/01689.png
# /kaggle/input/facial-key-point-data/images/04843.png
# /kaggle/input/facial-key-point-data/images/00965.png
# /kaggle/input/facial-key-point-data/images/01202.png
# /kaggle/input/facial-key-point-data/images/01895.png
# /kaggle/input/facial-key-point-data/images/00052.png
# /kaggle/input/facial-key-point-data/images/01739.png
# /kaggle/input/facial-key-point-data/images/03630.png
# /kaggle/input/facial-key-point-data/images/04281.png
# /kaggle/input/facial-key-point-data/images/03024.png
# /kaggle/input/facial-key-point-data/images/01867.png
# /kaggle/input/facial-key-point-data/images/01673.png
# /kaggle/input/facial-key-point-data/images/00173.png
# /kaggle/input/facial-key-point-data/images/04755.png
# /kaggle/input/facial-key-point-data/images/01036.png
# /kaggle/input/facial-key-point-data/images/03016.png
# /kaggle/input/facial-key-point-data/images/00468.png
# /kaggle/input/facial-key-point-data/images/02319.png
# /kaggle/input/facial-key-point-data/images/01741.png
# /kaggle/input/facial-key-point-data/images/00254.png
# /kaggle/input/facial-key-point-data/images/03717.png
# /kaggle/input/facial-key-point-data/images/01813.png
# /kaggle/input/facial-key-point-data/images/01537.png
# /kaggle/input/facial-key-point-data/images/01071.png
# /kaggle/input/facial-key-point-data/images/01730.png
# /kaggle/input/facial-key-point-data/images/04827.png
# /kaggle/input/facial-key-point-data/images/00570.png
# /kaggle/input/facial-key-point-data/images/00280.png
# /kaggle/input/facial-key-point-data/images/02629.png
# /kaggle/input/facial-key-point-data/images/03834.png
# /kaggle/input/facial-key-point-data/images/00578.png
# /kaggle/input/facial-key-point-data/images/01745.png
# /kaggle/input/facial-key-point-data/images/01598.png
# /kaggle/input/facial-key-point-data/images/04742.png
# /kaggle/input/facial-key-point-data/images/00515.png
# /kaggle/input/facial-key-point-data/images/01614.png
# /kaggle/input/facial-key-point-data/images/01329.png
# /kaggle/input/facial-key-point-data/images/03155.png
# /kaggle/input/facial-key-point-data/images/04867.png
# /kaggle/input/facial-key-point-data/images/00242.png
# /kaggle/input/facial-key-point-data/images/03405.png
# /kaggle/input/facial-key-point-data/images/03225.png
# /kaggle/input/facial-key-point-data/images/01171.png
# /kaggle/input/facial-key-point-data/images/03436.png
# /kaggle/input/facial-key-point-data/images/01949.png
# /kaggle/input/facial-key-point-data/images/03547.png
# /kaggle/input/facial-key-point-data/images/03160.png
# /kaggle/input/facial-key-point-data/images/04016.png
# /kaggle/input/facial-key-point-data/images/01061.png
# /kaggle/input/facial-key-point-data/images/00123.png
# /kaggle/input/facial-key-point-data/images/03377.png
# /kaggle/input/facial-key-point-data/images/04059.png
# /kaggle/input/facial-key-point-data/images/04041.png
# /kaggle/input/facial-key-point-data/images/00250.png
# /kaggle/input/facial-key-point-data/images/02195.png
# /kaggle/input/facial-key-point-data/images/02508.png
# /kaggle/input/facial-key-point-data/images/02939.png
# /kaggle/input/facial-key-point-data/images/01039.png
# /kaggle/input/facial-key-point-data/images/02887.png
# /kaggle/input/facial-key-point-data/images/01532.png
# /kaggle/input/facial-key-point-data/images/02510.png
# /kaggle/input/facial-key-point-data/images/04595.png
# /kaggle/input/facial-key-point-data/images/01057.png
# /kaggle/input/facial-key-point-data/images/01370.png
# /kaggle/input/facial-key-point-data/images/01379.png
# /kaggle/input/facial-key-point-data/images/00644.png
# /kaggle/input/facial-key-point-data/images/03238.png
# /kaggle/input/facial-key-point-data/images/02688.png
# /kaggle/input/facial-key-point-data/images/04228.png
# /kaggle/input/facial-key-point-data/images/01988.png
# /kaggle/input/facial-key-point-data/images/04409.png
# /kaggle/input/facial-key-point-data/images/02731.png
# /kaggle/input/facial-key-point-data/images/04586.png
# /kaggle/input/facial-key-point-data/images/03491.png
# /kaggle/input/facial-key-point-data/images/01652.png
# /kaggle/input/facial-key-point-data/images/03606.png
# /kaggle/input/facial-key-point-data/images/01030.png
# /kaggle/input/facial-key-point-data/images/02675.png
# /kaggle/input/facial-key-point-data/images/04202.png
# /kaggle/input/facial-key-point-data/images/04569.png
# /kaggle/input/facial-key-point-data/images/04590.png
# /kaggle/input/facial-key-point-data/images/04337.png
# /kaggle/input/facial-key-point-data/images/00535.png
# /kaggle/input/facial-key-point-data/images/02074.png
# /kaggle/input/facial-key-point-data/images/02537.png
# /kaggle/input/facial-key-point-data/images/04120.png
# /kaggle/input/facial-key-point-data/images/03915.png
# /kaggle/input/facial-key-point-data/images/03706.png
# /kaggle/input/facial-key-point-data/images/04873.png
# /kaggle/input/facial-key-point-data/images/02862.png
# /kaggle/input/facial-key-point-data/images/00549.png
# /kaggle/input/facial-key-point-data/images/01670.png
# /kaggle/input/facial-key-point-data/images/04457.png
# /kaggle/input/facial-key-point-data/images/00808.png
# /kaggle/input/facial-key-point-data/images/02075.png
# /kaggle/input/facial-key-point-data/images/02109.png
# /kaggle/input/facial-key-point-data/images/03143.png
# /kaggle/input/facial-key-point-data/images/03586.png
# /kaggle/input/facial-key-point-data/images/01278.png
# /kaggle/input/facial-key-point-data/images/01951.png
# /kaggle/input/facial-key-point-data/images/02912.png
# /kaggle/input/facial-key-point-data/images/01252.png
# /kaggle/input/facial-key-point-data/images/03025.png
# /kaggle/input/facial-key-point-data/images/02952.png
# /kaggle/input/facial-key-point-data/images/01518.png
# /kaggle/input/facial-key-point-data/images/01357.png
# /kaggle/input/facial-key-point-data/images/01477.png
# /kaggle/input/facial-key-point-data/images/02805.png
# /kaggle/input/facial-key-point-data/images/00122.png
# /kaggle/input/facial-key-point-data/images/02696.png
# /kaggle/input/facial-key-point-data/images/02353.png
# /kaggle/input/facial-key-point-data/images/02025.png
# /kaggle/input/facial-key-point-data/images/04456.png
# /kaggle/input/facial-key-point-data/images/04647.png
# /kaggle/input/facial-key-point-data/images/01990.png
# /kaggle/input/facial-key-point-data/images/03557.png
# /kaggle/input/facial-key-point-data/images/01209.png
# /kaggle/input/facial-key-point-data/images/00573.png
# /kaggle/input/facial-key-point-data/images/02776.png
# /kaggle/input/facial-key-point-data/images/04304.png
# /kaggle/input/facial-key-point-data/images/03700.png
# /kaggle/input/facial-key-point-data/images/04330.png
# /kaggle/input/facial-key-point-data/images/02013.png
# /kaggle/input/facial-key-point-data/images/01732.png
# /kaggle/input/facial-key-point-data/images/02726.png
# /kaggle/input/facial-key-point-data/images/02835.png
# /kaggle/input/facial-key-point-data/images/04787.png
# /kaggle/input/facial-key-point-data/images/03222.png
# /kaggle/input/facial-key-point-data/images/04662.png
# /kaggle/input/facial-key-point-data/images/04319.png
# /kaggle/input/facial-key-point-data/images/04399.png
# /kaggle/input/facial-key-point-data/images/02512.png
# /kaggle/input/facial-key-point-data/images/04080.png
# /kaggle/input/facial-key-point-data/images/04780.png
# /kaggle/input/facial-key-point-data/images/02831.png
# /kaggle/input/facial-key-point-data/images/01853.png
# /kaggle/input/facial-key-point-data/images/02038.png
# /kaggle/input/facial-key-point-data/images/00409.png
# /kaggle/input/facial-key-point-data/images/02119.png
# /kaggle/input/facial-key-point-data/images/03427.png
# /kaggle/input/facial-key-point-data/images/03965.png
# /kaggle/input/facial-key-point-data/images/03448.png
# /kaggle/input/facial-key-point-data/images/04365.png
# /kaggle/input/facial-key-point-data/images/03144.png
# /kaggle/input/facial-key-point-data/images/02026.png
# /kaggle/input/facial-key-point-data/images/02235.png
# /kaggle/input/facial-key-point-data/images/03184.png
# /kaggle/input/facial-key-point-data/images/04680.png
# /kaggle/input/facial-key-point-data/images/02851.png
# /kaggle/input/facial-key-point-data/images/03845.png
# /kaggle/input/facial-key-point-data/images/04868.png
# /kaggle/input/facial-key-point-data/images/01729.png
# /kaggle/input/facial-key-point-data/images/04693.png
# /kaggle/input/facial-key-point-data/images/03022.png
# /kaggle/input/facial-key-point-data/images/04466.png
# /kaggle/input/facial-key-point-data/images/01801.png
# /kaggle/input/facial-key-point-data/images/04029.png
# /kaggle/input/facial-key-point-data/images/01038.png
# /kaggle/input/facial-key-point-data/images/04918.png
# /kaggle/input/facial-key-point-data/images/04802.png
# /kaggle/input/facial-key-point-data/images/00973.png
# /kaggle/input/facial-key-point-data/images/04207.png
# /kaggle/input/facial-key-point-data/images/03179.png
# /kaggle/input/facial-key-point-data/images/01557.png
# /kaggle/input/facial-key-point-data/images/03710.png
# /kaggle/input/facial-key-point-data/images/02088.png
# /kaggle/input/facial-key-point-data/images/02452.png
# /kaggle/input/facial-key-point-data/images/03500.png
# /kaggle/input/facial-key-point-data/images/02411.png
# /kaggle/input/facial-key-point-data/images/00787.png
# /kaggle/input/facial-key-point-data/images/00743.png
# /kaggle/input/facial-key-point-data/images/03243.png
# /kaggle/input/facial-key-point-data/images/02245.png
# /kaggle/input/facial-key-point-data/images/00572.png
# /kaggle/input/facial-key-point-data/images/03670.png
# /kaggle/input/facial-key-point-data/images/04214.png
# /kaggle/input/facial-key-point-data/images/02607.png
# /kaggle/input/facial-key-point-data/images/01856.png
# /kaggle/input/facial-key-point-data/images/04584.png
# /kaggle/input/facial-key-point-data/images/02660.png
# /kaggle/input/facial-key-point-data/images/04862.png
# /kaggle/input/facial-key-point-data/images/04832.png
# /kaggle/input/facial-key-point-data/images/01177.png
# /kaggle/input/facial-key-point-data/images/01605.png
# /kaggle/input/facial-key-point-data/images/02290.png
# /kaggle/input/facial-key-point-data/images/00650.png
# /kaggle/input/facial-key-point-data/images/01917.png
# /kaggle/input/facial-key-point-data/images/04375.png
# /kaggle/input/facial-key-point-data/images/03324.png
# /kaggle/input/facial-key-point-data/images/03570.png
# /kaggle/input/facial-key-point-data/images/03408.png
# /kaggle/input/facial-key-point-data/images/02242.png
# /kaggle/input/facial-key-point-data/images/03516.png
# /kaggle/input/facial-key-point-data/images/03029.png
# /kaggle/input/facial-key-point-data/images/03743.png
# /kaggle/input/facial-key-point-data/images/01480.png
# /kaggle/input/facial-key-point-data/images/00373.png
# /kaggle/input/facial-key-point-data/images/00436.png
# /kaggle/input/facial-key-point-data/images/01720.png
# /kaggle/input/facial-key-point-data/images/02932.png
# /kaggle/input/facial-key-point-data/images/03884.png
# /kaggle/input/facial-key-point-data/images/03066.png
# /kaggle/input/facial-key-point-data/images/04651.png
# /kaggle/input/facial-key-point-data/images/02681.png
# /kaggle/input/facial-key-point-data/images/01910.png
# /kaggle/input/facial-key-point-data/images/00673.png
# /kaggle/input/facial-key-point-data/images/03273.png
# /kaggle/input/facial-key-point-data/images/00824.png
# /kaggle/input/facial-key-point-data/images/02918.png
# /kaggle/input/facial-key-point-data/images/00975.png
# /kaggle/input/facial-key-point-data/images/01715.png
# /kaggle/input/facial-key-point-data/images/00873.png
# /kaggle/input/facial-key-point-data/images/02172.png
# /kaggle/input/facial-key-point-data/images/01315.png
# /kaggle/input/facial-key-point-data/images/04021.png
# /kaggle/input/facial-key-point-data/images/03365.png
# /kaggle/input/facial-key-point-data/images/04408.png
# /kaggle/input/facial-key-point-data/images/03931.png
# /kaggle/input/facial-key-point-data/images/00283.png
# /kaggle/input/facial-key-point-data/images/00035.png
# /kaggle/input/facial-key-point-data/images/04577.png
# /kaggle/input/facial-key-point-data/images/03026.png
# /kaggle/input/facial-key-point-data/images/00730.png
# /kaggle/input/facial-key-point-data/images/04580.png
# /kaggle/input/facial-key-point-data/images/03370.png
# /kaggle/input/facial-key-point-data/images/01692.png
# /kaggle/input/facial-key-point-data/images/01763.png
# /kaggle/input/facial-key-point-data/images/04671.png
# /kaggle/input/facial-key-point-data/images/02816.png
# /kaggle/input/facial-key-point-data/images/01974.png
# /kaggle/input/facial-key-point-data/images/01287.png
# /kaggle/input/facial-key-point-data/images/04094.png
# /kaggle/input/facial-key-point-data/images/01733.png
# /kaggle/input/facial-key-point-data/images/00375.png
# /kaggle/input/facial-key-point-data/images/00475.png
# /kaggle/input/facial-key-point-data/images/01321.png
# /kaggle/input/facial-key-point-data/images/04083.png
# /kaggle/input/facial-key-point-data/images/00249.png
# /kaggle/input/facial-key-point-data/images/02935.png
# /kaggle/input/facial-key-point-data/images/02443.png
# /kaggle/input/facial-key-point-data/images/01459.png
# /kaggle/input/facial-key-point-data/images/02879.png
# /kaggle/input/facial-key-point-data/images/04977.png
# /kaggle/input/facial-key-point-data/images/00157.png
# /kaggle/input/facial-key-point-data/images/03199.png
# /kaggle/input/facial-key-point-data/images/02684.png
# /kaggle/input/facial-key-point-data/images/00679.png
# /kaggle/input/facial-key-point-data/images/02706.png
# /kaggle/input/facial-key-point-data/images/02440.png
# /kaggle/input/facial-key-point-data/images/00842.png
# /kaggle/input/facial-key-point-data/images/04449.png
# /kaggle/input/facial-key-point-data/images/03364.png
# /kaggle/input/facial-key-point-data/images/04895.png
# /kaggle/input/facial-key-point-data/images/00045.png
# /kaggle/input/facial-key-point-data/images/02421.png
# /kaggle/input/facial-key-point-data/images/02627.png
# /kaggle/input/facial-key-point-data/images/04559.png
# /kaggle/input/facial-key-point-data/images/04552.png
# /kaggle/input/facial-key-point-data/images/03435.png
# /kaggle/input/facial-key-point-data/images/00782.png
# /kaggle/input/facial-key-point-data/images/03002.png
# /kaggle/input/facial-key-point-data/images/00786.png
# /kaggle/input/facial-key-point-data/images/01333.png
# /kaggle/input/facial-key-point-data/images/01312.png
# /kaggle/input/facial-key-point-data/images/03261.png
# /kaggle/input/facial-key-point-data/images/02167.png
# /kaggle/input/facial-key-point-data/images/01244.png
# /kaggle/input/facial-key-point-data/images/02254.png
# /kaggle/input/facial-key-point-data/images/00691.png
# /kaggle/input/facial-key-point-data/images/02219.png
# /kaggle/input/facial-key-point-data/images/03515.png
# /kaggle/input/facial-key-point-data/images/03551.png
# /kaggle/input/facial-key-point-data/images/00555.png
# /kaggle/input/facial-key-point-data/images/04022.png
# /kaggle/input/facial-key-point-data/images/04619.png
# /kaggle/input/facial-key-point-data/images/03894.png
# /kaggle/input/facial-key-point-data/images/02906.png
# /kaggle/input/facial-key-point-data/images/02140.png
# /kaggle/input/facial-key-point-data/images/03800.png
# /kaggle/input/facial-key-point-data/images/02672.png
# /kaggle/input/facial-key-point-data/images/03992.png
# /kaggle/input/facial-key-point-data/images/02477.png
# /kaggle/input/facial-key-point-data/images/00038.png
# /kaggle/input/facial-key-point-data/images/00478.png
# /kaggle/input/facial-key-point-data/images/03961.png
# /kaggle/input/facial-key-point-data/images/04271.png
# /kaggle/input/facial-key-point-data/images/02442.png
# /kaggle/input/facial-key-point-data/images/00700.png
# /kaggle/input/facial-key-point-data/images/01528.png
# /kaggle/input/facial-key-point-data/images/03031.png
# /kaggle/input/facial-key-point-data/images/01091.png
# /kaggle/input/facial-key-point-data/images/04431.png
# /kaggle/input/facial-key-point-data/images/04374.png
# /kaggle/input/facial-key-point-data/images/02779.png
# /kaggle/input/facial-key-point-data/images/03404.png
# /kaggle/input/facial-key-point-data/images/01628.png
# /kaggle/input/facial-key-point-data/images/01317.png
# /kaggle/input/facial-key-point-data/images/01727.png
# /kaggle/input/facial-key-point-data/images/01378.png
# /kaggle/input/facial-key-point-data/images/03653.png
# /kaggle/input/facial-key-point-data/images/04023.png
# /kaggle/input/facial-key-point-data/images/03985.png
# /kaggle/input/facial-key-point-data/images/03836.png
# /kaggle/input/facial-key-point-data/images/01070.png
# /kaggle/input/facial-key-point-data/images/01677.png
# /kaggle/input/facial-key-point-data/images/03808.png
# /kaggle/input/facial-key-point-data/images/00398.png
# /kaggle/input/facial-key-point-data/images/04939.png
# /kaggle/input/facial-key-point-data/images/00594.png
# /kaggle/input/facial-key-point-data/images/01697.png
# /kaggle/input/facial-key-point-data/images/00507.png
# /kaggle/input/facial-key-point-data/images/02101.png
# /kaggle/input/facial-key-point-data/images/04324.png
# /kaggle/input/facial-key-point-data/images/02656.png
# /kaggle/input/facial-key-point-data/images/02737.png
# /kaggle/input/facial-key-point-data/images/03833.png
# /kaggle/input/facial-key-point-data/images/04486.png
# /kaggle/input/facial-key-point-data/images/03251.png
# /kaggle/input/facial-key-point-data/images/02060.png
# /kaggle/input/facial-key-point-data/images/04698.png
# /kaggle/input/facial-key-point-data/images/03754.png
# /kaggle/input/facial-key-point-data/images/03383.png
# /kaggle/input/facial-key-point-data/images/04801.png
# /kaggle/input/facial-key-point-data/images/01005.png
# /kaggle/input/facial-key-point-data/images/02130.png
# /kaggle/input/facial-key-point-data/images/01522.png
# /kaggle/input/facial-key-point-data/images/01086.png
# /kaggle/input/facial-key-point-data/images/00271.png
# /kaggle/input/facial-key-point-data/images/00505.png
# /kaggle/input/facial-key-point-data/images/04313.png
# /kaggle/input/facial-key-point-data/images/04444.png
# /kaggle/input/facial-key-point-data/images/01596.png
# /kaggle/input/facial-key-point-data/images/02826.png
# /kaggle/input/facial-key-point-data/images/02417.png
# /kaggle/input/facial-key-point-data/images/00606.png
# /kaggle/input/facial-key-point-data/images/04140.png
# /kaggle/input/facial-key-point-data/images/04113.png
# /kaggle/input/facial-key-point-data/images/04884.png
# /kaggle/input/facial-key-point-data/images/03345.png
# /kaggle/input/facial-key-point-data/images/01668.png
# /kaggle/input/facial-key-point-data/images/02875.png
# /kaggle/input/facial-key-point-data/images/01817.png
# /kaggle/input/facial-key-point-data/images/00176.png
# /kaggle/input/facial-key-point-data/images/04308.png
# /kaggle/input/facial-key-point-data/images/01608.png
# /kaggle/input/facial-key-point-data/images/02263.png
# /kaggle/input/facial-key-point-data/images/01194.png
# /kaggle/input/facial-key-point-data/images/02486.png
# /kaggle/input/facial-key-point-data/images/04523.png
# /kaggle/input/facial-key-point-data/images/00180.png
# /kaggle/input/facial-key-point-data/images/00025.png
# /kaggle/input/facial-key-point-data/images/03626.png
# /kaggle/input/facial-key-point-data/images/02910.png
# /kaggle/input/facial-key-point-data/images/03541.png
# /kaggle/input/facial-key-point-data/images/00968.png
# /kaggle/input/facial-key-point-data/images/01404.png
# /kaggle/input/facial-key-point-data/images/01268.png
# /kaggle/input/facial-key-point-data/images/03871.png
# /kaggle/input/facial-key-point-data/images/04048.png
# /kaggle/input/facial-key-point-data/images/02814.png
# /kaggle/input/facial-key-point-data/images/02348.png
# /kaggle/input/facial-key-point-data/images/00794.png
# /kaggle/input/facial-key-point-data/images/02802.png
# /kaggle/input/facial-key-point-data/images/01807.png
# /kaggle/input/facial-key-point-data/images/04367.png
# /kaggle/input/facial-key-point-data/images/03082.png
# /kaggle/input/facial-key-point-data/images/02339.png
# /kaggle/input/facial-key-point-data/images/04097.png
# /kaggle/input/facial-key-point-data/images/00836.png
# /kaggle/input/facial-key-point-data/images/00481.png
# /kaggle/input/facial-key-point-data/images/00702.png
# /kaggle/input/facial-key-point-data/images/03533.png
# /kaggle/input/facial-key-point-data/images/03112.png
# /kaggle/input/facial-key-point-data/images/03679.png
# /kaggle/input/facial-key-point-data/images/00104.png
# /kaggle/input/facial-key-point-data/images/01017.png
# /kaggle/input/facial-key-point-data/images/00312.png
# /kaggle/input/facial-key-point-data/images/00484.png
# /kaggle/input/facial-key-point-data/images/02277.png
# /kaggle/input/facial-key-point-data/images/04620.png
# /kaggle/input/facial-key-point-data/images/01604.png
# /kaggle/input/facial-key-point-data/images/01496.png
# /kaggle/input/facial-key-point-data/images/04754.png
# /kaggle/input/facial-key-point-data/images/02463.png
# /kaggle/input/facial-key-point-data/images/02091.png
# /kaggle/input/facial-key-point-data/images/02990.png
# /kaggle/input/facial-key-point-data/images/04808.png
# /kaggle/input/facial-key-point-data/images/04477.png
# /kaggle/input/facial-key-point-data/images/03644.png
# /kaggle/input/facial-key-point-data/images/01342.png
# /kaggle/input/facial-key-point-data/images/01872.png
# /kaggle/input/facial-key-point-data/images/04405.png
# /kaggle/input/facial-key-point-data/images/00109.png
# /kaggle/input/facial-key-point-data/images/00461.png
# /kaggle/input/facial-key-point-data/images/04338.png
# /kaggle/input/facial-key-point-data/images/00759.png
# /kaggle/input/facial-key-point-data/images/03007.png
# /kaggle/input/facial-key-point-data/images/02577.png
# /kaggle/input/facial-key-point-data/images/03009.png
# /kaggle/input/facial-key-point-data/images/00877.png
# /kaggle/input/facial-key-point-data/images/02832.png
# /kaggle/input/facial-key-point-data/images/00693.png
# /kaggle/input/facial-key-point-data/images/03668.png
# /kaggle/input/facial-key-point-data/images/01836.png
# /kaggle/input/facial-key-point-data/images/00531.png
# /kaggle/input/facial-key-point-data/images/04343.png
# /kaggle/input/facial-key-point-data/images/01116.png
# /kaggle/input/facial-key-point-data/images/04221.png
# /kaggle/input/facial-key-point-data/images/01603.png
# /kaggle/input/facial-key-point-data/images/00009.png
# /kaggle/input/facial-key-point-data/images/02921.png
# /kaggle/input/facial-key-point-data/images/02154.png
# /kaggle/input/facial-key-point-data/images/03127.png
# /kaggle/input/facial-key-point-data/images/03447.png
# /kaggle/input/facial-key-point-data/images/01185.png
# /kaggle/input/facial-key-point-data/images/02381.png
# /kaggle/input/facial-key-point-data/images/02573.png
# /kaggle/input/facial-key-point-data/images/00060.png
# /kaggle/input/facial-key-point-data/images/03081.png
# /kaggle/input/facial-key-point-data/images/04636.png
# /kaggle/input/facial-key-point-data/images/00362.png
# /kaggle/input/facial-key-point-data/images/04922.png
# /kaggle/input/facial-key-point-data/images/01247.png
# /kaggle/input/facial-key-point-data/images/00934.png
# /kaggle/input/facial-key-point-data/images/02391.png
# /kaggle/input/facial-key-point-data/images/04008.png
# /kaggle/input/facial-key-point-data/images/00835.png
# /kaggle/input/facial-key-point-data/images/02367.png
# /kaggle/input/facial-key-point-data/images/03587.png
# /kaggle/input/facial-key-point-data/images/02830.png
# /kaggle/input/facial-key-point-data/images/04262.png
# /kaggle/input/facial-key-point-data/images/04275.png
# /kaggle/input/facial-key-point-data/images/00031.png
# /kaggle/input/facial-key-point-data/images/03145.png
# /kaggle/input/facial-key-point-data/images/04264.png
# /kaggle/input/facial-key-point-data/images/00571.png
# /kaggle/input/facial-key-point-data/images/04709.png
# /kaggle/input/facial-key-point-data/images/02518.png
# /kaggle/input/facial-key-point-data/images/00264.png
# /kaggle/input/facial-key-point-data/images/00779.png
# /kaggle/input/facial-key-point-data/images/03851.png
# /kaggle/input/facial-key-point-data/images/01443.png
# /kaggle/input/facial-key-point-data/images/02493.png
# /kaggle/input/facial-key-point-data/images/02891.png
# /kaggle/input/facial-key-point-data/images/01950.png
# /kaggle/input/facial-key-point-data/images/01805.png
# /kaggle/input/facial-key-point-data/images/04794.png
# /kaggle/input/facial-key-point-data/images/01667.png
# /kaggle/input/facial-key-point-data/images/03071.png
# /kaggle/input/facial-key-point-data/images/04506.png
# /kaggle/input/facial-key-point-data/images/01619.png
# /kaggle/input/facial-key-point-data/images/01285.png
# /kaggle/input/facial-key-point-data/images/00331.png
# /kaggle/input/facial-key-point-data/images/00347.png
# /kaggle/input/facial-key-point-data/images/03413.png
# /kaggle/input/facial-key-point-data/images/04864.png
# /kaggle/input/facial-key-point-data/images/02024.png
# /kaggle/input/facial-key-point-data/images/03476.png
# /kaggle/input/facial-key-point-data/images/02854.png
# /kaggle/input/facial-key-point-data/images/02031.png
# /kaggle/input/facial-key-point-data/images/03172.png
# /kaggle/input/facial-key-point-data/images/02149.png
# /kaggle/input/facial-key-point-data/images/01613.png
# /kaggle/input/facial-key-point-data/images/04192.png
# /kaggle/input/facial-key-point-data/images/00387.png
# /kaggle/input/facial-key-point-data/images/03917.png
# /kaggle/input/facial-key-point-data/images/03187.png
# /kaggle/input/facial-key-point-data/images/00207.png
# /kaggle/input/facial-key-point-data/images/00948.png
# /kaggle/input/facial-key-point-data/images/01026.png
# /kaggle/input/facial-key-point-data/images/04714.png
# /kaggle/input/facial-key-point-data/images/02051.png
# /kaggle/input/facial-key-point-data/images/00856.png
# /kaggle/input/facial-key-point-data/images/00568.png
# /kaggle/input/facial-key-point-data/images/00989.png
# /kaggle/input/facial-key-point-data/images/03035.png
# /kaggle/input/facial-key-point-data/images/01143.png
# /kaggle/input/facial-key-point-data/images/04225.png
# /kaggle/input/facial-key-point-data/images/00407.png
# /kaggle/input/facial-key-point-data/images/00827.png
# /kaggle/input/facial-key-point-data/images/03954.png
# /kaggle/input/facial-key-point-data/images/00304.png
# /kaggle/input/facial-key-point-data/images/01997.png
# /kaggle/input/facial-key-point-data/images/04064.png
# /kaggle/input/facial-key-point-data/images/00369.png
# /kaggle/input/facial-key-point-data/images/00344.png
# /kaggle/input/facial-key-point-data/images/01444.png
# /kaggle/input/facial-key-point-data/images/02279.png
# /kaggle/input/facial-key-point-data/images/00432.png
# /kaggle/input/facial-key-point-data/images/04227.png
# /kaggle/input/facial-key-point-data/images/04360.png
# /kaggle/input/facial-key-point-data/images/01903.png
# /kaggle/input/facial-key-point-data/images/01906.png
# /kaggle/input/facial-key-point-data/images/01058.png
# /kaggle/input/facial-key-point-data/images/02478.png
# /kaggle/input/facial-key-point-data/images/02295.png
# /kaggle/input/facial-key-point-data/images/03742.png
# /kaggle/input/facial-key-point-data/images/00241.png
# /kaggle/input/facial-key-point-data/images/03973.png
# /kaggle/input/facial-key-point-data/images/00721.png
# /kaggle/input/facial-key-point-data/images/00059.png
# /kaggle/input/facial-key-point-data/images/04193.png
# /kaggle/input/facial-key-point-data/images/00070.png
# /kaggle/input/facial-key-point-data/images/00506.png
# /kaggle/input/facial-key-point-data/images/04237.png
# /kaggle/input/facial-key-point-data/images/00675.png
# /kaggle/input/facial-key-point-data/images/02521.png
# /kaggle/input/facial-key-point-data/images/00941.png
# /kaggle/input/facial-key-point-data/images/02287.png
# /kaggle/input/facial-key-point-data/images/00153.png
# /kaggle/input/facial-key-point-data/images/03093.png
# /kaggle/input/facial-key-point-data/images/01753.png
# /kaggle/input/facial-key-point-data/images/02141.png
# /kaggle/input/facial-key-point-data/images/00927.png
# /kaggle/input/facial-key-point-data/images/00256.png
# /kaggle/input/facial-key-point-data/images/00107.png
# /kaggle/input/facial-key-point-data/images/04626.png
# /kaggle/input/facial-key-point-data/images/03838.png
# /kaggle/input/facial-key-point-data/images/04341.png
# /kaggle/input/facial-key-point-data/images/03195.png
# /kaggle/input/facial-key-point-data/images/03892.png
# /kaggle/input/facial-key-point-data/images/01832.png
# /kaggle/input/facial-key-point-data/images/01225.png
# /kaggle/input/facial-key-point-data/images/02638.png
# /kaggle/input/facial-key-point-data/images/01316.png
# /kaggle/input/facial-key-point-data/images/00379.png
# /kaggle/input/facial-key-point-data/images/00191.png
# /kaggle/input/facial-key-point-data/images/02653.png
# /kaggle/input/facial-key-point-data/images/00165.png
# /kaggle/input/facial-key-point-data/images/00236.png
# /kaggle/input/facial-key-point-data/images/03424.png
# /kaggle/input/facial-key-point-data/images/04220.png
# /kaggle/input/facial-key-point-data/images/00401.png
# /kaggle/input/facial-key-point-data/images/01610.png
# /kaggle/input/facial-key-point-data/images/00206.png
# /kaggle/input/facial-key-point-data/images/00067.png
# /kaggle/input/facial-key-point-data/images/00671.png
# /kaggle/input/facial-key-point-data/images/00341.png
# /kaggle/input/facial-key-point-data/images/04490.png
# /kaggle/input/facial-key-point-data/images/03287.png
# /kaggle/input/facial-key-point-data/images/02899.png
# /kaggle/input/facial-key-point-data/images/00892.png
# /kaggle/input/facial-key-point-data/images/00717.png
# /kaggle/input/facial-key-point-data/images/03598.png
# /kaggle/input/facial-key-point-data/images/04986.png
# /kaggle/input/facial-key-point-data/images/04148.png
# /kaggle/input/facial-key-point-data/images/00662.png
# /kaggle/input/facial-key-point-data/images/00265.png
# /kaggle/input/facial-key-point-data/images/01089.png
# /kaggle/input/facial-key-point-data/images/01505.png
# /kaggle/input/facial-key-point-data/images/02894.png
# /kaggle/input/facial-key-point-data/images/00357.png
# /kaggle/input/facial-key-point-data/images/01189.png
# /kaggle/input/facial-key-point-data/images/01545.png
# /kaggle/input/facial-key-point-data/images/00811.png
# /kaggle/input/facial-key-point-data/images/03255.png
# /kaggle/input/facial-key-point-data/images/00203.png
# /kaggle/input/facial-key-point-data/images/03018.png
# /kaggle/input/facial-key-point-data/images/03048.png
# /kaggle/input/facial-key-point-data/images/04335.png
# /kaggle/input/facial-key-point-data/images/01823.png
# /kaggle/input/facial-key-point-data/images/03104.png
# /kaggle/input/facial-key-point-data/images/04739.png
# /kaggle/input/facial-key-point-data/images/04715.png
# /kaggle/input/facial-key-point-data/images/03281.png
# /kaggle/input/facial-key-point-data/images/03544.png
# /kaggle/input/facial-key-point-data/images/04298.png
# /kaggle/input/facial-key-point-data/images/01991.png
# /kaggle/input/facial-key-point-data/images/04639.png
# /kaggle/input/facial-key-point-data/images/01591.png
# /kaggle/input/facial-key-point-data/images/00429.png
# /kaggle/input/facial-key-point-data/images/03247.png
# /kaggle/input/facial-key-point-data/images/04267.png
# /kaggle/input/facial-key-point-data/images/03400.png
# /kaggle/input/facial-key-point-data/images/01597.png
# /kaggle/input/facial-key-point-data/images/00770.png
# /kaggle/input/facial-key-point-data/images/01770.png
# /kaggle/input/facial-key-point-data/images/03779.png
# /kaggle/input/facial-key-point-data/images/01590.png
# /kaggle/input/facial-key-point-data/images/03354.png
# /kaggle/input/facial-key-point-data/images/03554.png
# /kaggle/input/facial-key-point-data/images/03332.png
# /kaggle/input/facial-key-point-data/images/00229.png
# /kaggle/input/facial-key-point-data/images/02781.png
# /kaggle/input/facial-key-point-data/images/02107.png
# /kaggle/input/facial-key-point-data/images/03793.png
# /kaggle/input/facial-key-point-data/images/02798.png
# /kaggle/input/facial-key-point-data/images/01451.png
# /kaggle/input/facial-key-point-data/images/03263.png
# /kaggle/input/facial-key-point-data/images/02177.png
# /kaggle/input/facial-key-point-data/images/01192.png
# /kaggle/input/facial-key-point-data/images/04260.png
# /kaggle/input/facial-key-point-data/images/01376.png
# /kaggle/input/facial-key-point-data/images/03924.png
# /kaggle/input/facial-key-point-data/images/00613.png
# /kaggle/input/facial-key-point-data/images/00744.png
# /kaggle/input/facial-key-point-data/images/00309.png
# /kaggle/input/facial-key-point-data/images/01418.png
# /kaggle/input/facial-key-point-data/images/04013.png
# /kaggle/input/facial-key-point-data/images/00131.png
# /kaggle/input/facial-key-point-data/images/00184.png
# /kaggle/input/facial-key-point-data/images/02187.png
# /kaggle/input/facial-key-point-data/images/00692.png
# /kaggle/input/facial-key-point-data/images/02503.png
# /kaggle/input/facial-key-point-data/images/01325.png
# /kaggle/input/facial-key-point-data/images/01625.png
# /kaggle/input/facial-key-point-data/images/03731.png
# /kaggle/input/facial-key-point-data/images/02983.png
# /kaggle/input/facial-key-point-data/images/00539.png
# /kaggle/input/facial-key-point-data/images/03669.png
# /kaggle/input/facial-key-point-data/images/04347.png
# /kaggle/input/facial-key-point-data/images/00186.png
# /kaggle/input/facial-key-point-data/images/02928.png
# /kaggle/input/facial-key-point-data/images/01777.png
# /kaggle/input/facial-key-point-data/images/04473.png
# /kaggle/input/facial-key-point-data/images/00777.png
# /kaggle/input/facial-key-point-data/images/00720.png
# /kaggle/input/facial-key-point-data/images/00516.png
# /kaggle/input/facial-key-point-data/images/04111.png
# /kaggle/input/facial-key-point-data/images/04924.png
# /kaggle/input/facial-key-point-data/images/02065.png
# /kaggle/input/facial-key-point-data/images/02597.png
# /kaggle/input/facial-key-point-data/images/00247.png
# /kaggle/input/facial-key-point-data/images/02144.png
# /kaggle/input/facial-key-point-data/images/03462.png
# /kaggle/input/facial-key-point-data/images/01173.png
# /kaggle/input/facial-key-point-data/images/03267.png
# /kaggle/input/facial-key-point-data/images/02301.png
# /kaggle/input/facial-key-point-data/images/03111.png
# /kaggle/input/facial-key-point-data/images/01155.png
# /kaggle/input/facial-key-point-data/images/02396.png
# /kaggle/input/facial-key-point-data/images/02749.png
# /kaggle/input/facial-key-point-data/images/01012.png
# /kaggle/input/facial-key-point-data/images/01372.png
# /kaggle/input/facial-key-point-data/images/00729.png
# /kaggle/input/facial-key-point-data/images/04694.png
# /kaggle/input/facial-key-point-data/images/00006.png
# /kaggle/input/facial-key-point-data/images/01010.png
# /kaggle/input/facial-key-point-data/images/00044.png
# /kaggle/input/facial-key-point-data/images/00661.png
# /kaggle/input/facial-key-point-data/images/03128.png
# /kaggle/input/facial-key-point-data/images/04521.png
# /kaggle/input/facial-key-point-data/images/04280.png
# /kaggle/input/facial-key-point-data/images/03173.png
# /kaggle/input/facial-key-point-data/images/01960.png
# /kaggle/input/facial-key-point-data/images/04607.png
# /kaggle/input/facial-key-point-data/images/00054.png
# /kaggle/input/facial-key-point-data/images/04700.png
# /kaggle/input/facial-key-point-data/images/03108.png
# /kaggle/input/facial-key-point-data/images/04608.png
# /kaggle/input/facial-key-point-data/images/04833.png
# /kaggle/input/facial-key-point-data/images/00624.png
# /kaggle/input/facial-key-point-data/images/01547.png
# /kaggle/input/facial-key-point-data/images/02439.png
# /kaggle/input/facial-key-point-data/images/02978.png
# /kaggle/input/facial-key-point-data/images/04381.png
# /kaggle/input/facial-key-point-data/images/02504.png
# /kaggle/input/facial-key-point-data/images/04141.png
# /kaggle/input/facial-key-point-data/images/01703.png
# /kaggle/input/facial-key-point-data/images/01633.png
# /kaggle/input/facial-key-point-data/images/02828.png
# /kaggle/input/facial-key-point-data/images/04551.png
# /kaggle/input/facial-key-point-data/images/01045.png
# /kaggle/input/facial-key-point-data/images/01049.png
# /kaggle/input/facial-key-point-data/images/03701.png
# /kaggle/input/facial-key-point-data/images/02412.png
# /kaggle/input/facial-key-point-data/images/03266.png
# /kaggle/input/facial-key-point-data/images/02401.png
# /kaggle/input/facial-key-point-data/images/00099.png
# /kaggle/input/facial-key-point-data/images/00784.png
# /kaggle/input/facial-key-point-data/images/01690.png
# /kaggle/input/facial-key-point-data/images/01128.png
# /kaggle/input/facial-key-point-data/images/02415.png
# /kaggle/input/facial-key-point-data/images/03643.png
# /kaggle/input/facial-key-point-data/images/04528.png
# /kaggle/input/facial-key-point-data/images/02923.png
# /kaggle/input/facial-key-point-data/images/01764.png
# /kaggle/input/facial-key-point-data/images/04487.png
# /kaggle/input/facial-key-point-data/images/00445.png
# /kaggle/input/facial-key-point-data/images/03130.png
# /kaggle/input/facial-key-point-data/images/01863.png
# /kaggle/input/facial-key-point-data/images/03001.png
# /kaggle/input/facial-key-point-data/images/02982.png
# /kaggle/input/facial-key-point-data/images/02686.png
# /kaggle/input/facial-key-point-data/images/03746.png
# /kaggle/input/facial-key-point-data/images/01876.png
# /kaggle/input/facial-key-point-data/images/01167.png
# /kaggle/input/facial-key-point-data/images/04557.png
# /kaggle/input/facial-key-point-data/images/02271.png
# /kaggle/input/facial-key-point-data/images/02846.png
# /kaggle/input/facial-key-point-data/images/01985.png
# /kaggle/input/facial-key-point-data/images/02615.png
# /kaggle/input/facial-key-point-data/images/03293.png
# /kaggle/input/facial-key-point-data/images/02930.png
# /kaggle/input/facial-key-point-data/images/04401.png
# /kaggle/input/facial-key-point-data/images/02773.png
# /kaggle/input/facial-key-point-data/images/02570.png
# /kaggle/input/facial-key-point-data/images/00750.png
# /kaggle/input/facial-key-point-data/images/03189.png
# /kaggle/input/facial-key-point-data/images/01260.png
# /kaggle/input/facial-key-point-data/images/00974.png
# /kaggle/input/facial-key-point-data/images/01873.png
# /kaggle/input/facial-key-point-data/images/04982.png
# /kaggle/input/facial-key-point-data/images/04087.png
# /kaggle/input/facial-key-point-data/images/01000.png
# /kaggle/input/facial-key-point-data/images/02888.png
# /kaggle/input/facial-key-point-data/images/00148.png
# /kaggle/input/facial-key-point-data/images/01583.png
# /kaggle/input/facial-key-point-data/images/02794.png
# /kaggle/input/facial-key-point-data/images/01543.png
# /kaggle/input/facial-key-point-data/images/02033.png
# /kaggle/input/facial-key-point-data/images/04050.png
# /kaggle/input/facial-key-point-data/images/01844.png
# /kaggle/input/facial-key-point-data/images/00971.png
# /kaggle/input/facial-key-point-data/images/04818.png
# /kaggle/input/facial-key-point-data/images/03723.png
# /kaggle/input/facial-key-point-data/images/03072.png
# /kaggle/input/facial-key-point-data/images/01472.png
# /kaggle/input/facial-key-point-data/images/00447.png
# /kaggle/input/facial-key-point-data/images/00924.png
# /kaggle/input/facial-key-point-data/images/04567.png
# /kaggle/input/facial-key-point-data/images/00270.png
# /kaggle/input/facial-key-point-data/images/02194.png
# /kaggle/input/facial-key-point-data/images/02513.png
# /kaggle/input/facial-key-point-data/images/02566.png
# /kaggle/input/facial-key-point-data/images/02955.png
# /kaggle/input/facial-key-point-data/images/03664.png
# /kaggle/input/facial-key-point-data/images/02016.png
# /kaggle/input/facial-key-point-data/images/04971.png
# /kaggle/input/facial-key-point-data/images/02865.png
# /kaggle/input/facial-key-point-data/images/04455.png
# /kaggle/input/facial-key-point-data/images/00449.png
# /kaggle/input/facial-key-point-data/images/00262.png
# /kaggle/input/facial-key-point-data/images/00785.png
# /kaggle/input/facial-key-point-data/images/00713.png
# /kaggle/input/facial-key-point-data/images/03585.png
# /kaggle/input/facial-key-point-data/images/02892.png
# /kaggle/input/facial-key-point-data/images/03888.png
# /kaggle/input/facial-key-point-data/images/00093.png
# /kaggle/input/facial-key-point-data/images/00581.png
# /kaggle/input/facial-key-point-data/images/03314.png
# /kaggle/input/facial-key-point-data/images/01456.png
# /kaggle/input/facial-key-point-data/images/01452.png
# /kaggle/input/facial-key-point-data/images/04253.png
# /kaggle/input/facial-key-point-data/images/00614.png
# ...
# /kaggle/input/facial-key-point-data/images/00682.png
# /kaggle/input/facial-key-point-data/images/03919.png
# /kaggle/input/facial-key-point-data/images/01166.png
# /kaggle/input/facial-key-point-data/images/02467.png
# /kaggle/input/facial-key-point-data/images/01525.png
# /kaggle/input/facial-key-point-data/images/01406.png
# /kaggle/input/facial-key-point-data/images/04363.png
# /kaggle/input/facial-key-point-data/images/02820.png
# /kaggle/input/facial-key-point-data/images/03011.png
# /kaggle/input/facial-key-point-data/images/00906.png
# /kaggle/input/facial-key-point-data/images/04591.png
# /kaggle/input/facial-key-point-data/images/00518.png
# /kaggle/input/facial-key-point-data/images/02608.png
# /kaggle/input/facial-key-point-data/images/00431.png
# /kaggle/input/facial-key-point-data/images/03068.png
# /kaggle/input/facial-key-point-data/images/00629.png
# /kaggle/input/facial-key-point-data/images/03063.png
# /kaggle/input/facial-key-point-data/images/03910.png
# /kaggle/input/facial-key-point-data/images/01978.png
# /kaggle/input/facial-key-point-data/images/01818.png
# /kaggle/input/facial-key-point-data/images/03215.png
# /kaggle/input/facial-key-point-data/images/02155.png
# /kaggle/input/facial-key-point-data/images/01283.png
# /kaggle/input/facial-key-point-data/images/04592.png
# /kaggle/input/facial-key-point-data/images/04131.png
# /kaggle/input/facial-key-point-data/images/04211.png
# /kaggle/input/facial-key-point-data/images/02480.png
# /kaggle/input/facial-key-point-data/images/04624.png
# /kaggle/input/facial-key-point-data/images/01009.png
# /kaggle/input/facial-key-point-data/images/02762.png
# /kaggle/input/facial-key-point-data/images/01403.png
# /kaggle/input/facial-key-point-data/images/01218.png
# /kaggle/input/facial-key-point-data/images/00427.png
# /kaggle/input/facial-key-point-data/images/00188.png
# /kaggle/input/facial-key-point-data/images/02937.png
# /kaggle/input/facial-key-point-data/images/02703.png
# /kaggle/input/facial-key-point-data/images/03241.png
# /kaggle/input/facial-key-point-data/images/00396.png
# /kaggle/input/facial-key-point-data/images/02933.png
# /kaggle/input/facial-key-point-data/images/04451.png
# /kaggle/input/facial-key-point-data/images/02837.png
# /kaggle/input/facial-key-point-data/images/03012.png
# /kaggle/input/facial-key-point-data/images/01433.png
# /kaggle/input/facial-key-point-data/images/01107.png
# /kaggle/input/facial-key-point-data/images/03358.png
# /kaggle/input/facial-key-point-data/images/02201.png
# /kaggle/input/facial-key-point-data/images/02967.png
# /kaggle/input/facial-key-point-data/images/00393.png
# /kaggle/input/facial-key-point-data/images/00154.png
# /kaggle/input/facial-key-point-data/images/01508.png
# /kaggle/input/facial-key-point-data/images/02583.png
# /kaggle/input/facial-key-point-data/images/00913.png
# /kaggle/input/facial-key-point-data/images/00485.png
# /kaggle/input/facial-key-point-data/images/00640.png
# /kaggle/input/facial-key-point-data/images/01152.png
# /kaggle/input/facial-key-point-data/images/00301.png
# /kaggle/input/facial-key-point-data/images/01831.png
# /kaggle/input/facial-key-point-data/images/00796.png
# /kaggle/input/facial-key-point-data/images/04786.png
# /kaggle/input/facial-key-point-data/images/03681.png
# /kaggle/input/facial-key-point-data/images/00959.png
# /kaggle/input/facial-key-point-data/images/00263.png
# /kaggle/input/facial-key-point-data/images/01270.png
# /kaggle/input/facial-key-point-data/images/02264.png
# /kaggle/input/facial-key-point-data/images/03661.png
# /kaggle/input/facial-key-point-data/images/04269.png
# /kaggle/input/facial-key-point-data/images/02810.png
# /kaggle/input/facial-key-point-data/images/03849.png
# /kaggle/input/facial-key-point-data/images/01382.png
# /kaggle/input/facial-key-point-data/images/04189.png
# /kaggle/input/facial-key-point-data/images/04371.png
# /kaggle/input/facial-key-point-data/images/00915.png
# /kaggle/input/facial-key-point-data/images/03325.png
# /kaggle/input/facial-key-point-data/images/02811.png
# /kaggle/input/facial-key-point-data/images/03386.png
# /kaggle/input/facial-key-point-data/images/01712.png
# /kaggle/input/facial-key-point-data/images/00005.png
# /kaggle/input/facial-key-point-data/images/03003.png
# /kaggle/input/facial-key-point-data/images/02941.png
# /kaggle/input/facial-key-point-data/images/00684.png
# /kaggle/input/facial-key-point-data/images/04690.png
# /kaggle/input/facial-key-point-data/images/04099.png
# /kaggle/input/facial-key-point-data/images/00443.png
# /kaggle/input/facial-key-point-data/images/04665.png
# /kaggle/input/facial-key-point-data/images/03350.png
# /kaggle/input/facial-key-point-data/images/00522.png
# /kaggle/input/facial-key-point-data/images/01358.png
# /kaggle/input/facial-key-point-data/images/02166.png
# /kaggle/input/facial-key-point-data/images/02190.png
# /kaggle/input/facial-key-point-data/images/02270.png
# /kaggle/input/facial-key-point-data/images/03615.png
# /kaggle/input/facial-key-point-data/images/04395.png
# /kaggle/input/facial-key-point-data/images/00482.png
# /kaggle/input/facial-key-point-data/images/03682.png
# /kaggle/input/facial-key-point-data/images/03191.png
# /kaggle/input/facial-key-point-data/images/02175.png
# /kaggle/input/facial-key-point-data/images/04492.png
# /kaggle/input/facial-key-point-data/images/03856.png
# /kaggle/input/facial-key-point-data/images/00579.png
# /kaggle/input/facial-key-point-data/images/03369.png
# /kaggle/input/facial-key-point-data/images/03477.png
# /kaggle/input/facial-key-point-data/images/03970.png
# /kaggle/input/facial-key-point-data/images/03086.png
# /kaggle/input/facial-key-point-data/images/02329.png
# /kaggle/input/facial-key-point-data/images/00618.png
# /kaggle/input/facial-key-point-data/images/01139.png
# /kaggle/input/facial-key-point-data/images/03600.png
# /kaggle/input/facial-key-point-data/images/03873.png
# /kaggle/input/facial-key-point-data/images/00164.png
# /kaggle/input/facial-key-point-data/images/03955.png
# /kaggle/input/facial-key-point-data/images/04287.png
# /kaggle/input/facial-key-point-data/images/04004.png
# /kaggle/input/facial-key-point-data/images/04194.png
# /kaggle/input/facial-key-point-data/images/03194.png
# /kaggle/input/facial-key-point-data/images/04931.png
# /kaggle/input/facial-key-point-data/images/02448.png
# /kaggle/input/facial-key-point-data/images/00741.png
# /kaggle/input/facial-key-point-data/images/01640.png
# /kaggle/input/facial-key-point-data/images/03869.png
# /kaggle/input/facial-key-point-data/images/01776.png
# /kaggle/input/facial-key-point-data/images/03136.png
# /kaggle/input/facial-key-point-data/images/03902.png
# /kaggle/input/facial-key-point-data/images/00306.png
# /kaggle/input/facial-key-point-data/images/01616.png
# /kaggle/input/facial-key-point-data/images/04558.png
# /kaggle/input/facial-key-point-data/images/02062.png
# /kaggle/input/facial-key-point-data/images/03656.png
# /kaggle/input/facial-key-point-data/images/03315.png
# /kaggle/input/facial-key-point-data/images/04328.png
# /kaggle/input/facial-key-point-data/images/02861.png
# /kaggle/input/facial-key-point-data/images/00211.png
# /kaggle/input/facial-key-point-data/images/04010.png
# /kaggle/input/facial-key-point-data/images/01565.png
# /kaggle/input/facial-key-point-data/images/03488.png
# /kaggle/input/facial-key-point-data/images/04340.png
# /kaggle/input/facial-key-point-data/images/03654.png
# /kaggle/input/facial-key-point-data/images/03903.png
# /kaggle/input/facial-key-point-data/images/00420.png
# /kaggle/input/facial-key-point-data/images/03257.png
# /kaggle/input/facial-key-point-data/images/01007.png
# /kaggle/input/facial-key-point-data/images/02131.png
# /kaggle/input/facial-key-point-data/images/03051.png
# /kaggle/input/facial-key-point-data/images/00788.png
# /kaggle/input/facial-key-point-data/images/01812.png
# /kaggle/input/facial-key-point-data/images/00002.png
# /kaggle/input/facial-key-point-data/images/00697.png
# /kaggle/input/facial-key-point-data/images/01800.png
# /kaggle/input/facial-key-point-data/images/03707.png
# /kaggle/input/facial-key-point-data/images/01644.png
# /kaggle/input/facial-key-point-data/images/00500.png
# /kaggle/input/facial-key-point-data/images/02903.png
# /kaggle/input/facial-key-point-data/images/00258.png
# /kaggle/input/facial-key-point-data/images/01815.png
# /kaggle/input/facial-key-point-data/images/01755.png
# /kaggle/input/facial-key-point-data/images/00171.png
# /kaggle/input/facial-key-point-data/images/01615.png
# /kaggle/input/facial-key-point-data/images/02699.png
# /kaggle/input/facial-key-point-data/images/00895.png
# /kaggle/input/facial-key-point-data/images/00663.png
# /kaggle/input/facial-key-point-data/images/01908.png
# /kaggle/input/facial-key-point-data/images/00763.png
# /kaggle/input/facial-key-point-data/images/04032.png
# /kaggle/input/facial-key-point-data/images/00047.png
# /kaggle/input/facial-key-point-data/images/02603.png
# /kaggle/input/facial-key-point-data/images/04480.png
# /kaggle/input/facial-key-point-data/images/04539.png
# /kaggle/input/facial-key-point-data/images/02152.png
# /kaggle/input/facial-key-point-data/images/01306.png
# /kaggle/input/facial-key-point-data/images/04034.png
# /kaggle/input/facial-key-point-data/images/00068.png
# /kaggle/input/facial-key-point-data/images/00360.png
# /kaggle/input/facial-key-point-data/images/02976.png
# /kaggle/input/facial-key-point-data/images/02097.png
# /kaggle/input/facial-key-point-data/images/01228.png
# /kaggle/input/facial-key-point-data/images/01385.png
# /kaggle/input/facial-key-point-data/images/04689.png
# /kaggle/input/facial-key-point-data/images/04540.png
# /kaggle/input/facial-key-point-data/images/03501.png
# /kaggle/input/facial-key-point-data/images/02356.png
# /kaggle/input/facial-key-point-data/images/03169.png
# /kaggle/input/facial-key-point-data/images/04565.png
# /kaggle/input/facial-key-point-data/images/04071.png
# /kaggle/input/facial-key-point-data/images/03296.png
# /kaggle/input/facial-key-point-data/images/00958.png
# /kaggle/input/facial-key-point-data/images/01885.png
# /kaggle/input/facial-key-point-data/images/04012.png
# /kaggle/input/facial-key-point-data/images/04464.png
# /kaggle/input/facial-key-point-data/images/01078.png
# /kaggle/input/facial-key-point-data/images/01593.png
# /kaggle/input/facial-key-point-data/images/03579.png
# /kaggle/input/facial-key-point-data/images/00670.png
# /kaggle/input/facial-key-point-data/images/00707.png
# /kaggle/input/facial-key-point-data/images/04210.png
# /kaggle/input/facial-key-point-data/images/03804.png
# /kaggle/input/facial-key-point-data/images/03868.png
# /kaggle/input/facial-key-point-data/images/01174.png
# /kaggle/input/facial-key-point-data/images/01826.png
# /kaggle/input/facial-key-point-data/images/02400.png
# /kaggle/input/facial-key-point-data/images/03510.png
# /kaggle/input/facial-key-point-data/images/01566.png
# /kaggle/input/facial-key-point-data/images/04515.png
# /kaggle/input/facial-key-point-data/images/02784.png
# /kaggle/input/facial-key-point-data/images/02514.png
# /kaggle/input/facial-key-point-data/images/03268.png
# /kaggle/input/facial-key-point-data/images/04306.png
# /kaggle/input/facial-key-point-data/images/00820.png
# /kaggle/input/facial-key-point-data/images/01449.png
# /kaggle/input/facial-key-point-data/images/00231.png
# /kaggle/input/facial-key-point-data/images/04951.png
# /kaggle/input/facial-key-point-data/images/02965.png
# /kaggle/input/facial-key-point-data/images/01931.png
# /kaggle/input/facial-key-point-data/images/02331.png
# /kaggle/input/facial-key-point-data/images/01076.png
# /kaggle/input/facial-key-point-data/images/02040.png
# /kaggle/input/facial-key-point-data/images/04093.png
# /kaggle/input/facial-key-point-data/images/02308.png
# /kaggle/input/facial-key-point-data/images/01577.png
# /kaggle/input/facial-key-point-data/images/04026.png
# /kaggle/input/facial-key-point-data/images/00416.png
# /kaggle/input/facial-key-point-data/images/04076.png
# /kaggle/input/facial-key-point-data/images/04650.png
# /kaggle/input/facial-key-point-data/images/01246.png
# /kaggle/input/facial-key-point-data/images/00860.png
# /kaggle/input/facial-key-point-data/images/00412.png
# /kaggle/input/facial-key-point-data/images/04871.png
# /kaggle/input/facial-key-point-data/images/00085.png
# /kaggle/input/facial-key-point-data/images/04283.png
# /kaggle/input/facial-key-point-data/images/02388.png
# /kaggle/input/facial-key-point-data/images/01059.png
# /kaggle/input/facial-key-point-data/images/00551.png
# /kaggle/input/facial-key-point-data/images/04379.png
# /kaggle/input/facial-key-point-data/images/04106.png
# /kaggle/input/facial-key-point-data/images/02057.png
# /kaggle/input/facial-key-point-data/images/03105.png
# /kaggle/input/facial-key-point-data/images/03840.png
# /kaggle/input/facial-key-point-data/images/01168.png
# /kaggle/input/facial-key-point-data/images/03820.png
# /kaggle/input/facial-key-point-data/images/03753.png
# /kaggle/input/facial-key-point-data/images/04073.png
# /kaggle/input/facial-key-point-data/images/04625.png
# /kaggle/input/facial-key-point-data/images/03393.png
# /kaggle/input/facial-key-point-data/images/00472.png
# /kaggle/input/facial-key-point-data/images/03819.png
# /kaggle/input/facial-key-point-data/images/02244.png
# /kaggle/input/facial-key-point-data/images/04406.png
# /kaggle/input/facial-key-point-data/images/00053.png
# /kaggle/input/facial-key-point-data/images/04238.png
# /kaggle/input/facial-key-point-data/images/00893.png
# /kaggle/input/facial-key-point-data/images/00831.png
# /kaggle/input/facial-key-point-data/images/01599.png
# /kaggle/input/facial-key-point-data/images/01084.png
# /kaggle/input/facial-key-point-data/images/02623.png
# /kaggle/input/facial-key-point-data/images/03563.png
# /kaggle/input/facial-key-point-data/images/04446.png
# /kaggle/input/facial-key-point-data/images/02980.png
# /kaggle/input/facial-key-point-data/images/02267.png
# /kaggle/input/facial-key-point-data/images/01904.png
# /kaggle/input/facial-key-point-data/images/00825.png
# /kaggle/input/facial-key-point-data/images/03737.png
# /kaggle/input/facial-key-point-data/images/01551.png
# /kaggle/input/facial-key-point-data/images/01627.png
# /kaggle/input/facial-key-point-data/images/01201.png
# /kaggle/input/facial-key-point-data/images/03133.png
# /kaggle/input/facial-key-point-data/images/01214.png
# /kaggle/input/facial-key-point-data/images/00890.png
# /kaggle/input/facial-key-point-data/images/02819.png
# /kaggle/input/facial-key-point-data/images/02890.png
# /kaggle/input/facial-key-point-data/images/02556.png
# /kaggle/input/facial-key-point-data/images/00732.png
# /kaggle/input/facial-key-point-data/images/04897.png
# /kaggle/input/facial-key-point-data/images/02408.png
# /kaggle/input/facial-key-point-data/images/04383.png
# /kaggle/input/facial-key-point-data/images/01424.png
# /kaggle/input/facial-key-point-data/images/02827.png
# /kaggle/input/facial-key-point-data/images/00233.png
# /kaggle/input/facial-key-point-data/images/03935.png
# /kaggle/input/facial-key-point-data/images/02285.png
# /kaggle/input/facial-key-point-data/images/02349.png
# /kaggle/input/facial-key-point-data/images/03282.png
# /kaggle/input/facial-key-point-data/images/00872.png
# /kaggle/input/facial-key-point-data/images/02714.png
# /kaggle/input/facial-key-point-data/images/01083.png
# /kaggle/input/facial-key-point-data/images/03937.png
# /kaggle/input/facial-key-point-data/images/00908.png
# /kaggle/input/facial-key-point-data/images/03158.png
# /kaggle/input/facial-key-point-data/images/01148.png
# /kaggle/input/facial-key-point-data/images/02803.png
# /kaggle/input/facial-key-point-data/images/02590.png
# /kaggle/input/facial-key-point-data/images/01780.png
# /kaggle/input/facial-key-point-data/images/03432.png
# /kaggle/input/facial-key-point-data/images/01474.png
# /kaggle/input/facial-key-point-data/images/02210.png
# /kaggle/input/facial-key-point-data/images/04445.png
# /kaggle/input/facial-key-point-data/images/04563.png
# /kaggle/input/facial-key-point-data/images/02739.png
# /kaggle/input/facial-key-point-data/images/00291.png
# /kaggle/input/facial-key-point-data/images/03152.png
# /kaggle/input/facial-key-point-data/images/04741.png
# /kaggle/input/facial-key-point-data/images/01982.png
# /kaggle/input/facial-key-point-data/images/04356.png
# /kaggle/input/facial-key-point-data/images/01632.png

# %%
import cv2
import os
from PIL import Image

# Define the paths
input_folder = '/kaggle/input/facial-key-point-data/images'
new_size = (256, 256)  # Desired size

# Load the pre-trained Haar Cascade model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def get_landmarks(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    landmarks = []
    for (x, y, w, h) in faces:
        # Extract the center of the bounding box as a simple landmark
        center_x = x + w // 2
        center_y = y + h // 2
        landmarks.append((center_x, center_y))
    return landmarks

# Define the maximum number of landmarks expected
MAX_LANDMARKS = 68  # Change this based on your requirements
landmark_dim = 2    # Each landmark as (x, y)

# Lists to store processed images and landmarks
processed_images = []
all_landmarks = []

# Iterate over all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path)
        img = img.resize(new_size, Image.LANCZOS)  # Resize the image using LANCZOS filter

        img_np = np.array(img)  # Convert image to numpy array

        # Detect landmarks
        landmarks = get_landmarks(img_np)

        # Pad landmarks if necessary
        if len(landmarks) < MAX_LANDMARKS:
            landmarks.extend([(0, 0)] * (MAX_LANDMARKS - len(landmarks)))
        else:
            landmarks = landmarks[:MAX_LANDMARKS]

        all_landmarks.append(landmarks)

        # Append resized image to list
        processed_images.append(img_np)

# Convert lists to numpy arrays
processed_images_np = np.array(processed_images) / 255.0  # Normalize images
all_landmarks_np = np.array(all_landmarks)

# Save the processed data
np.save("processed_images.npy", processed_images_np)  # Save images
np.save("facial_landmarks.npy", all_landmarks_np)  # Save landmarks

# Output sizes of the saved arrays
print(f"Processed images shape: {processed_images_np.shape}")
print(f"Facial landmarks shape: {all_landmarks_np.shape}")
# Out:
# Processed images shape: (5000, 256, 256, 3)
# Facial landmarks shape: (5000, 68, 2)

# %%
# !pip install keras-tuner  --upgrade
# Out:
# Requirement already satisfied: keras-tuner in /opt/conda/lib/python3.10/site-packages (1.4.7)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (3.3.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (0.3.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->keras-tuner) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (2024.7.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import keras_tuner as kt
from sklearn.model_selection import train_test_split

# Assuming your dataset is available in the Kaggle environment
# If your data is saved as npy files, you can load them like this
processed_images = np.load("processed_images.npy")  # Update the path if needed
facial_landmarks = np.load("facial_landmarks.npy")  # Update the path if needed

# %%
# Reshape facial landmarks to (5000, 136) to match output of Dense layer
facial_landmarks = facial_landmarks.reshape((facial_landmarks.shape[0], 68 * 2))

# Split the dataset into training and validation
x_train, x_val, y_train, y_val = train_test_split(processed_images, facial_landmarks, test_size=0.2, random_state=42)

# %%
# Function to build the model with Keras Tuner
def build_model(hp):
    model = models.Sequential()

    # Add Convolutional layers
    for i in range(hp.Int('conv_blocks', 1, 3, default=2)):
        model.add(layers.Conv2D(
            filters=hp.Int(f'filters_{i}', min_value=32, max_value=128, step=32),
            kernel_size=hp.Choice(f'kernel_size_{i}', values=[3, 5]),
            activation='relu',
            input_shape=(256, 256, 3) if i == 0 else None
        ))
        model.add(layers.MaxPooling2D(pool_size=2))

    # Flatten before Dense layers
    model.add(layers.Flatten())

    # Add fully connected layers
    model.add(layers.Dense(hp.Int('dense_units', min_value=64, max_value=256, step=64), activation='relu'))

    # Output layer for 68 landmarks (136 values)
    model.add(layers.Dense(136))


    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss='mean_squared_error',
                  metrics=['mae'])

    return model

# %%
# Set up the Keras Tuner for hyperparameter optimization
tuner = kt.RandomSearch(
    build_model,
    objective='val_mae',  # We aim to minimize the Mean Absolute Error
    max_trials=2,         # Number of different models to try
    executions_per_trial=1,  # Number of times to train each model (1 for speed)
    directory='/kaggle/working/nas_landmark_detection',  # Save the search results here
    project_name='cnn_nas'  # Name of the project
)

# Summary of search space
tuner.search_space_summary()

# Run the hyperparameter search
tuner.search(x_train, y_train, epochs=10, validation_data=(x_val, y_val))

# Get the best model after the search
best_model = tuner.get_best_models(num_models=1)[0]

# Display a summary of the best model
best_model.summary()
# Out:
# Trial 2 Complete [00h 02m 04s]
# val_mae: 0.6321548819541931
#
# Best val_mae So Far: 0.6321548819541931
# Total elapsed time: 00h 07m 32s
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 252, 252, 64)   │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 126, 126, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 124, 124, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 492032)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │   125,960,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 136)            │        34,952 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 126,074,120 (480.93 MB)
#  Trainable params: 126,074,120 (480.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Optionally, evaluate the best model on the validation set
val_loss, val_mae = best_model.evaluate(x_val, y_val)
print(f"Validation Loss: {val_loss}, Validation MAE: {val_mae}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 25.9029 - mae: 0.6330
# Validation Loss: 26.350666046142578, Validation MAE: 0.6321548819541931
